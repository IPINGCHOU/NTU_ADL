# %%
import sys
sys.path.append("/disk2/iping/NTU_ADL/ADL_hw1/hw1_sample_code/src")

import os
import pickle
from argparse import Namespace
from typing import Tuple, Dict
import random

import torch
from torch import nn
from torch.utils.data import DataLoader
import pytorch_lightning as pl
import torch.nn.functional as F

from dataset import Seq2SeqDataset
from pytorch_lightning.callbacks import ModelCheckpoint

# %%
class Encoder(nn.Module):
    def __init__(self, embedding_path, emb_dim, enc_hid_dim, enc_layers, dec_hid_dim, enc_dropout):
        super(Encoder, self).__init__()
        with open(embedding_path, 'rb') as f:
            embedding = pickle.load(f)
        embedding_weight = embedding.vectors
        self.embedding = nn.Embedding.from_pretrained(embedding_weight)
        
        self.emb_dim = emb_dim
        self.enc_hid_dim = enc_hid_dim
        self.enc_layers = enc_layers
        self.enc_dropout = enc_dropout
        
        self.rnn = nn.GRU(input_size = emb_dim,
                          hidden_size = enc_hid_dim,
                          num_layers = enc_layers,
                          bidirectional = True,
                          batch_first = False)
        
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        self.dropout = nn.Dropout(enc_dropout)

    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, hidden = self.rnn(embedded)
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        return outputs, hidden    

class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()        
        self.attn = nn.Linear((enc_hid_dim * 2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias = False)
        
    def forward(self, hidden, encoder_outputs):
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2))) 
        attention = self.v(energy).squeeze(2)
        return F.softmax(attention, dim=1)
    
class Decoder(nn.Module):
    def __init__(self, embedding_path, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dec_dropout, dec_num_layers, attention):
        super().__init__()

        with open(embedding_path, 'rb') as f:
            embedding = pickle.load(f)
        embedding_weight = embedding.vectors
        self.embedding = nn.Embedding.from_pretrained(embedding_weight)
        self.output_dim = output_dim
        
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        self.fc_out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dec_dropout)
        self.attention = attention
        
    def forward(self, input, hidden, encoder_outputs):

        input = input.unsqueeze(0)
        embedded = self.dropout(self.embedding(input))
        
        a = self.attention(hidden, encoder_outputs)
        a = a.unsqueeze(1)
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        weighted = torch.bmm(a, encoder_outputs)
        weighted = weighted.permute(1, 0, 2)
        
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))

        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))

        return prediction, hidden.squeeze(0)

class Seq2Seq_attn(pl.LightningModule):
    def __init__(self, hparams) -> None:
        super(Seq2Seq_attn, self).__init__()
        self.hparams = hparams
        self.criterion = nn.CrossEntropyLoss(ignore_index = self.hparams.ignore_idx)
        attn = Attention(hparams.enc_hid_dim,
                         hparams.dec_hid_dim)
        self.encoder = Encoder(hparams.embedding_path,
                               hparams.emb_dim,
                               hparams.enc_hid_dim,
                               hparams.enc_num_layers,
                               hparams.dec_hid_dim,
                               hparams.enc_dropout)
        self.decoder = Decoder(hparams.embedding_path,
                               hparams.output_dim,
                               hparams.emb_dim,
                               hparams.enc_hid_dim,
                               hparams.dec_hid_dim,
                               hparams.dec_dropout,
                               hparams.dec_num_layers,
                               attn)

    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        batch_size = src.shape[1]
        trg_vocab_size = self.decoder.output_dim
                
        if trg != 'test':
            input = trg[0,:]
            trg_len = trg.shape[0]

            outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.hparams.device)
            encoder_outputs, hidden = self.encoder(src)
            for t in range(1, trg_len):
                output, hidden = self.decoder(input, hidden, encoder_outputs)
                outputs[t] = output
                teacher_force = random.random() > teacher_forcing_ratio
                top1 = output.argmax(1) 
                input = trg[t] if teacher_force else top1
        else:
            input = torch.ones(batch_size).to(device = self.hparams.device, dtype=torch.int64)
            trg_len = 80
            outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.hparams.device)
            encoder_outputs, hidden = self.encoder(src)
            for t in range(1, trg_len):
                output, hidden = self.decoder(input, hidden, encoder_outputs)
                outputs[t] = output
                input = output.argmax(1) 

        return outputs

    def _unpack_batch(self, batch) -> Tuple[torch.tensor, torch.tensor]:
        try:
            return batch['text'], batch['summary']
        except:
            return batch['text']

    def _calculate_loss(self, output, trg) -> torch.tensor:
        # TODO
        # calculate the logits
        # plz use BCEWithLogit
        # adjust pos_weight!
        # MASK OUT PADDINGS' LOSSES!
        
        output_dim = output.shape[-1]
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].reshape(-1)
        
        loss = self.criterion(output, trg)
        
        return loss

    def training_step(self, batch, batch_nb) -> Dict:
        x, y = self._unpack_batch(batch)
        x = x.permute(1,0)
        y = y.permute(1,0)
        output = self.forward(x,y)
        loss = self._calculate_loss(output, y)
        tensorboard_logs = {'train_loss': loss}
        return {'loss': loss, 'log': tensorboard_logs}

    def validation_step(self, batch, batch_nb) -> Dict:
        x, y = self._unpack_batch(batch)
        x = x.permute(1,0)
        y = y.permute(1,0)
        output = self.forward(x,y)
        loss = self._calculate_loss(output, y)
        return {'val_loss': loss}
    
    def validation_epoch_end(self, outputs) -> Dict:
        avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
        tensorboard_logs = {'val_loss': avg_loss}
        return {'avg_val_loss': avg_loss, 'log': tensorboard_logs}
    
    def configure_optimizers(self) -> torch.optim.Optimizer:
        return torch.optim.Adam(self.parameters(), lr=self.hparams.lr)

    def _load_dataset(self, dataset_path: str) -> Seq2SeqDataset:
        with open(dataset_path, 'rb') as f:
            dataset = pickle.load(f)
        return dataset

    def train_dataloader(self):
        dataset = self._load_dataset(self.hparams.train_dataset_path)
        return DataLoader(dataset, 
                          self.hparams.batch_size, 
                          shuffle=True,
                          collate_fn=dataset.collate_fn)

    def val_dataloader(self):
        dataset = self._load_dataset(self.hparams.valid_dataset_path)
        return DataLoader(dataset, 
                          self.hparams.batch_size, 
                          collate_fn=dataset.collate_fn)
    
class MyPrintingCallback(pl.Callback):
    
    def on_validation_start(self, trainer, pl_module):
        print('validation starts')
        
    def on_validation_end(self, trainer, pl_module):
        print('validation end')

# %%
data_path = '/disk2/iping/NTU_ADL/ADL_hw1/data'
hparams = Namespace(**{
    'embedding_path': data_path + "/embedding_seq2seq.pkl",
    'train_dataset_path': data_path + "/train_seq2seq.pkl",
    'valid_dataset_path': data_path + "/valid_seq2seq.pkl",
    
    'ignore_idx': 0,
    'batch_size': 32,
    
    'emb_dim' : 300,
    'enc_hid_dim' : 256,
    'enc_num_layers' : 1,
    'enc_dropout' : 0,
    
    'output_dim' : 97513,
    'dec_hid_dim' : 256,
    'dec_dropout' : 0,
    'dec_num_layers': 1,
    
    'device': 'cuda:1',

    'lr': 1e-04,
})

# %%
PATH_checkpoint = "/disk2/iping/NTU_ADL/ADL_hw1/seq2seq_attn_model/"
PATH_checkpoint += "model_attn_lr1e04_{epoch:02d}"

checkpoint_callback = ModelCheckpoint(
    filepath=PATH_checkpoint,
    save_top_k=True,
    verbose=True,
    monitor='avg_val_loss',
    mode='min',
    prefix=''
)

seq2seq_attn = Seq2Seq_attn(hparams)
trainer = pl.Trainer(gpus=[1], max_epochs=20, checkpoint_callback=checkpoint_callback)
trainer.fit(seq2seq_attn)
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# HBox(children=(FloatProgress(value=0.0, description='Validation sanity check', layout=Layout(flex='2'), max=5.…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), max=1.0), HTML(value='')), …
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Validating', layout=Layout(flex='2'), max=625.0, style=Pr…
# 1

# %%
from tqdm import tqdm
PATH_checkpoint = "/disk2/iping/NTU_ADL/ADL_hw1/seq2seq_attn_model/"
PATH_checkpoint += "model_attn_lr1e04_epoch=19.ckpt"
seq2seq_attn = Seq2Seq_attn.load_from_checkpoint(PATH_checkpoint)

# %%
# if pl test doesnt work
with open(data_path + "/valid_seq2seq.pkl", 'rb') as f:
    dataset = pickle.load(f)
test_loader = DataLoader(dataset, 
                         32, 
                         collate_fn=dataset.collate_fn)
device = hparams.device
print(device)
trange_test = tqdm(enumerate(test_loader), total=len(test_loader), desc = 'Test')
ans = []
seq2seq_attn.train(False)
log_softmax = nn.LogSoftmax(dim=-1)
for z, (batch) in trange_test:
    x,_ = seq2seq_attn._unpack_batch(batch)
    x = x.to(device)
    x = x.permute(1,0)
    seq2seq_attn.to(device)
    output = seq2seq_attn.forward(x, 'test', 0)
    output = log_softmax(output)
    output = torch.argmax(output.permute(1,0,2), axis = 2)    
    output = output.type(torch.int64).tolist()
    ans.extend(output)
# Out:
# Test:   0%|          | 0/625 [00:00<?, ?it/s]
# cuda:1
# Test: 100%|██████████| 625/625 [05:12<00:00,  2.00it/s]

# %%
data_path = '/disk2/iping/NTU_ADL/ADL_hw1/data'
with open(data_path + "/embedding_seq2seq.pkl", 'rb') as f:
    embed_dataset = pickle.load(f)
with open(data_path + "/valid_seq2seq.pkl", 'rb') as f:
    valid_dataset = pickle.load(f)

# %%
import numpy as np
ans_jsonl = []
for data, a in zip(valid_dataset, ans):
    now_sent = ''
    for i in a:
        if i != 2:
            now_vocab = embed_dataset.vocab[i]
            now_sent = now_sent + now_vocab + ' '
        else:
            now_sent = now_sent[:-6]
            now_sent = now_sent[7:]
            break
    ans_jsonl.append({'id':data['id'], 'predict': now_sent})

# %%
ans_jsonl
# Out:
# [{'id': '2000000',
#   'predict': 'a rare of of a a - old - old - has been given a a to a new . . '},
#  {'id': '2000001',
#   'predict': 'a council has has been to to a council council tax authority ( <unk> ) in the . '},
#  {'id': '2000002',
#   'predict': "a giant robot has invented a robot designed to be built in the world 's biggest ever . "},
#  {'id': '2000003',
#   'predict': 'a of the uk \'s longest aircraft has been postponed because of the shoreham air disaster " . '},
#  {'id': '2000004',
#   'predict': 'the us basketball player has been the us of the " after the " of the " " " the " " . '},
#  {'id': '2000005',
#   'predict': "scotland 's mark allen has his his to win the world championship title with a second - round win over the world championship . "},
#  {'id': '2000006',
#   'predict': "newport county 's newport county championship play - off places as they beat newport county to play - off . "},
#  {'id': '2000007',
#   'predict': '<unk> wood scored a hat - trick as they beat the to earn a national league win at the national league . '},
#  {'id': '2000008',
#   'predict': 'graeme mcdowell carded a a - under - par 65 to lead a a - shot lead at the the round of the the open . '},
#  {'id': '2000009',
#   'predict': 'sussex have signed former has signed a new contract with the club until the end of the season . '},
#  {'id': '2000010',
#   'predict': 'the rnli has has been the to the the of the to the the who died at the . '},
#  {'id': '2000011',
#   'predict': 'a new has been unveiled to a new of the city centre in the city of the . '},
#  {'id': '2000012',
#   'predict': "ireland 's their first - match in the first - finals of the women 's first - match in the first - in the . "},
#  {'id': '2000013',
#   'predict': 'sri lanka have <unk> <unk> has been banned for a months after admitting a a a - of the . '},
#  {'id': '2000014',
#   'predict': 'sunderland midfielder harry kane has signed a new contract with the league one side . '},
#  {'id': '2000015',
#   'predict': 'former england boss sam allardyce says he is " to " " " " " the england \'s the england . '},
#  {'id': '2000016',
#   'predict': 'a letter written a " of " " of " has been reunited with a after a a a . '},
#  {'id': '2000017',
#   'predict': 'a man has died after being found in a car in in the republic of '},
#  {'id': '2000018',
#   'predict': 'league one side <unk> <unk> has been banned from the football association after the body of the football association . '},
#  {'id': '2000019',
#   'predict': 'a controversial plans to a a new park in the has been a the city of '},
#  {'id': '2000020',
#   'predict': 'a british woman who was a in a a in the has been a to the the of the , the , the has said . '},
#  {'id': '2000021',
#   'predict': 'drones has drones are being drones to drones drones are to to drones , a new report . '},
#  {'id': '2000022',
#   'predict': 'england pace bowler <unk> <unk> has been ruled out of the rest of the season after suffering a a shoulder injury . '},
#  {'id': '2000023',
#   'predict': "swansea city 's new cinema cinema cinema has been has been given a new - . "},
#  {'id': '2000024',
#   'predict': 'the european court has has has tested positive " " " " " " " " " " " . '},
#  {'id': '2000025',
#   'predict': 'former england have appointed former england and - back - back from the for the club . '},
#  {'id': '2000026',
#   'predict': 'the has approved a new of to to the to of the to the to the to the . '},
#  {'id': '2000027',
#   'predict': 'a new has been a to build a derelict - of a derelict in in a . '},
#  {'id': '2000028',
#   'predict': "the number of people living in the uk 's most popular of , has been , according to the , according to the . "},
#  {'id': '2000029',
#   'predict': 'a " extremely " " " " " " " " " " " " " " " " " a " - old " of a " . '},
#  {'id': '2000030',
#   'predict': "the 's president has has a new president of the party party party party party . "},
#  {'id': '2000031',
#   'predict': 'dundee united have signed <unk> has signed a new contract with the club . '},
#  {'id': '2000032',
#   'predict': 'former labour mp <unk> has has said he is " to " the " of the " . '},
#  {'id': '2000033',
#   'predict': 'league one side signed town have signed midfielder <unk> <unk> on a one - year deal . '},
#  {'id': '2000034',
#   'predict': '<unk> climbed a from the league two - as they beat to a a - - 0 win over the . '},
#  {'id': '2000035',
#   'predict': 'police in the have been a a of a a a photo of a man who was a in a . '},
#  {'id': '2000036',
#   'predict': 'a rare of a horse has been found in a a of a a of a a . '},
#  {'id': '2000037',
#   'predict': 'heavy rain and heavy rain and heavy rain and wales are being warned to be aware . '},
#  {'id': '2000038',
#   'predict': "the remains of the world 's largest world war two years ago has been discovered in the world war two years ago . "},
#  {'id': '2000039',
#   'predict': 'former police mp mp has been arrested on suspicion of a police on a referendum . '},
#  {'id': '2000040',
#   'predict': 'newport county have signed former midfielder county defender kyle clarke on loan until the end of the season . '},
#  {'id': '2000041',
#   'predict': 'a student has a a to a a a a a a a a has been a a " a " " . '},
#  {'id': '2000042',
#   'predict': 'a \'s supreme court has ruled that he is " to " " " " the " " , the " . '},
#  {'id': '2000043',
#   'predict': "<unk> will host the icc of the icc women 's icc in the , the the the the the 's icc . "},
#  {'id': '2000044',
#   'predict': 'a man has been arrested on a racist abuse " violent " " in a " violent " " . '},
#  {'id': '2000045',
#   'predict': 'more than 100 people have to be held in the and strike in the , the , the '},
#  {'id': '2000046',
#   'predict': 'police are investigating the disappearance of a man who went missing in a a in in a . '},
#  {'id': '2000047',
#   'predict': 'two men who died in a explosion explosion at a flat in in the have been named . '},
#  {'id': '2000048',
#   'predict': "the 's of the is to be the the the the the the the the the the the . "},
#  {'id': '2000049',
#   'predict': 'a rare of prey has been spotted in the scottish of of scotland . '},
#  {'id': '2000050',
#   'predict': 'a man has been charged with connection with a driving of a car in a . '},
#  {'id': '2000051',
#   'predict': 'itv \'s has has has been the bbc radio 4 - the bbc radio 4 - after the was " by the " . '},
#  {'id': '2000052',
#   'predict': 'former united manager michael appleton has said he is " to " the " to " the " the " . '},
#  {'id': '2000053',
#   'predict': 'a least 50 people have been killed in a landslide in in the in the capital of the , the . '},
#  {'id': '2000054',
#   'predict': 'a man has died after a fire at a house in edinburgh . '},
#  {'id': '2000055',
#   'predict': "<unk> <unk> 's a - - of the season as they were beaten by the in the league one of the . "},
#  {'id': '2000056',
#   'predict': 'a man has been charged with sexual assault of a man in a . '},
#  {'id': '2000057',
#   'predict': 'wales \'s labour mp has said she is " " " " " " , the " , the welsh government has said . '},
#  {'id': '2000058',
#   'predict': 'heavy rain has been issued for parts of scotland and galloway and galloway and galloway . '},
#  {'id': '2000059',
#   'predict': 'the northern ireland has been a record record for the first time in the . '},
#  {'id': '2000060',
#   'predict': 'taylor swift has been the first of the most popular of of the , , , , has been announced . '},
#  {'id': '2000061',
#   'predict': 'a woman has been a court in the a of a woman who died after a crash crash in a . '},
#  {'id': '2000062',
#   'predict': 'eastleigh boss neil warnock says he is " to his side \'s to the the of the - 0 win over morecambe . '},
#  {'id': '2000063',
#   'predict': 'a roman mosaic has been to the a of a century century century , has been to be demolished . '},
#  {'id': '2000064',
#   'predict': 'a of a " water " " " " of the " of the " of the , has been found in the . '},
#  {'id': '2000065',
#   'predict': 'a former manchester united fan who has been his first - after the a of a to the the . '},
#  {'id': '2000066',
#   'predict': 'translink has announced a new - of the to the in the to of the , the . '},
#  {'id': '2000067',
#   'predict': 'the supermarket of the has the uk \'s to the the the of the " of the " , the " . '},
#  {'id': '2000068',
#   'predict': 'england have signed australia international cricket - rounder ben stokes on a one - year deal . '},
#  {'id': '2000069',
#   'predict': 'league one side rochdale have signed midfielder midfielder - back on loan until the end of the season . '},
#  {'id': '2000070',
#   'predict': 'linfield have signed a signing of the signing of the premiership club linfield for a season - year deal . '},
#  {'id': '2000071',
#   'predict': 'the of the of the most of of the most famous , , , , according to the . '},
#  {'id': '2000072',
#   'predict': 'eastleigh town manager paul tisdale says he is " to " the " after the his contract with the league one . '},
#  {'id': '2000073',
#   'predict': 'a man has been found guilty of murdering a woman in a a in a " of " " . '},
#  {'id': '2000074',
#   'predict': 'a man who stole a a " " " " " has been jailed for '},
#  {'id': '2000075',
#   'predict': 'a new medical equipment is to be the in northern ireland '},
#  {'id': '2000076',
#   'predict': "a new £ m m project to build a £ in m in the uk 's largest economy , has been announced . "},
#  {'id': '2000077',
#   'predict': 'a former teacher who sexually abused a young girls in a has been jailed for sexually abusing a girls . '},
#  {'id': '2000078',
#   'predict': 'a us has been killed in a crash in the saudi arabia , killing a least people people . '},
#  {'id': '2000079',
#   'predict': 'cardiff airport has announced plans to increase its busiest airports in cardiff . '},
#  {'id': '2000080',
#   'predict': 'a man has been arrested on suspicion of attempted robbery at a shop shop in <unk> . '},
#  {'id': '2000081',
#   'predict': 'wales coach coach warren says the will not " " " " " the " " the " of the " . '},
#  {'id': '2000082',
#   'predict': "australia 's government has said it will not to to to the to the the to the the country 's "},
#  {'id': '2000083',
#   'predict': 'a mother of a woman who killed a mother - a - a crash in a crash on a has been jailed for '},
#  {'id': '2000084',
#   'predict': 'a cyclist has died after a crash in a lorry in a . '},
#  {'id': '2000085',
#   'predict': 'us - based firm adidas <unk> has reported a sharp fall in profits for the year of the year . '},
#  {'id': '2000086',
#   'predict': "the actor and actor and the the the the the the awards at the year 's awards awards awards . "},
#  {'id': '2000087',
#   'predict': 'national league side have have signed former - back - back from <unk> on a two - year deal . '},
#  {'id': '2000088',
#   'predict': 'a former man has been jailed for a a a a a a a a a a a a a a a " of " " . '},
#  {'id': '2000089',
#   'predict': 'a suspected of of a have been arrested in the - called islamic state ( is ) in the , '},
#  {'id': '2000090',
#   'predict': 'cardiff city have signed cardiff city centre - back - back on loan until the end of the season . '},
#  {'id': '2000091',
#   'predict': 'the us government has has prisoners have been sentenced to prison sentences for the prisoners in prison . '},
#  {'id': '2000092',
#   'predict': "michael hutchinson 's the fastest pace to the the fastest pace to the the the of the tt races in the . "},
#  {'id': '2000093',
#   'predict': 'families of families affected in the families affected in the county londonderry . '},
#  {'id': '2000094',
#   'predict': "manchester city 's a a for the premier league title with a comfortable win over the in the premier league . "},
#  {'id': '2000095',
#   'predict': 'this year , the the a few of the year , but of a lot of the the . '},
#  {'id': '2000096',
#   'predict': "lincoln city 's a - half - half - off places to a comfortable win at the national league . "},
#  {'id': '2000097',
#   'predict': 'a former who of a a a a a a a a a court has been jailed for a years . '},
#  {'id': '2000098',
#   'predict': 'a cinema cinema cinema cinema cinema has been to be redeveloped in a bid to save it it it " . '},
#  {'id': '2000099',
#   'predict': 'a man accused of a a of of a a of a in a has appeared in court charged with assault . '},
#  {'id': '2000100',
#   'predict': "ireland 's ibf world champion champion <unk> will fight a unanimous points to the the the the the the world . "},
#  {'id': '2000101',
#   'predict': "kent 's batsmen dominated a one - day as they beat derbyshire and middlesex beat middlesex at the . "},
#  {'id': '2000102',
#   'predict': 'sunderland united have appointed former coach coach coach coach on a new head coach . '},
#  {'id': '2000103',
#   'predict': 'a man who admitted a a baby - year - old girl in a has been jailed for six months . '},
#  {'id': '2000104',
#   'predict': 'a of tickets tickets have to be held in glasgow to the the to the the the of the . '},
#  {'id': '2000105',
#   'predict': 'the welsh government will be the to to the welsh government to the the welsh government has been . '},
#  {'id': '2000106',
#   'predict': 'a family of a man who was in a a nightclub in a has been named as a " attack . '},
#  {'id': '2000107',
#   'predict': 'rail services are to be to to a new rail station in the to a new rail station . '},
#  {'id': '2000108',
#   'predict': 'a fire has been rescued after a fire at a house in in . '},
#  {'id': '2000109',
#   'predict': 'a of of prey in wales has been a rare of extinction " . '},
#  {'id': '2000110',
#   'predict': 'the company company has has been a to a £ in m in a £ <unk> m in a . '},
#  {'id': '2000111',
#   'predict': "wales 's kris <unk> has been his first in the world championship in the after a 1 - 1 win over the . "},
#  {'id': '2000112',
#   'predict': 'a former marine football has has been suspended from the after the after he was in a a in the . '},
#  {'id': '2000113',
#   'predict': 'a man who used a guns and ammunition and ammunition and ammunition and ammunition and ammunition and ammunition and ammunition and ammunition , has been jailed for '},
#  {'id': '2000114',
#   'predict': 'a suicide bomber has been killed in a bomb attack in the sinai peninsula in the , , officials say . '},
#  {'id': '2000115',
#   'predict': "the northern ireland 's northern ireland has been to to the % in the , the , the report . "},
#  {'id': '2000116',
#   'predict': 'a school has been evacuated after a after a was closed to a a of a " . '},
#  {'id': '2000117',
#   'predict': 'a man has been arrested on suspicion of murdering a man who was stabbed in a in london . '},
#  {'id': '2000118',
#   'predict': "england 's - back to the the the the the the the the the the the the the the . "},
#  {'id': '2000119',
#   'predict': "southend united 's a league one play - off places as they beat off to the league one play - off places . "},
#  {'id': '2000120',
#   'predict': 'swindon town manager paul robinson has left his contract with the league one club . '},
#  {'id': '2000121',
#   'predict': 'police police will be a a to a the to to the the to the the of the '},
#  {'id': '2000122',
#   'predict': 'wasps director of rugby dai <unk> says he is " " " " " " " " " " " " " " " . '},
#  {'id': '2000123',
#   'predict': 'sri lankan president <unk> <unk> has said he will not be a " to the the of the country \'s '},
#  {'id': '2000124',
#   'predict': "britain 's secured a gold medal in the world m breaststroke m breaststroke m breaststroke m breaststroke m breaststroke in the european championships in the . "},
#  {'id': '2000125',
#   'predict': 'the family of a man who died in a has been found in a has been found in the . '},
#  {'id': '2000126',
#   'predict': 'a man who died after a crash in a a has died in a . '},
#  {'id': '2000127',
#   'predict': 'the scottish government has has to sell a £ to m in the scottish borders . '},
#  {'id': '2000128',
#   'predict': 'a parents who a man who was a a a a a a a a a a a a a . '},
#  {'id': '2000129',
#   'predict': 'a lorry has been injured after a car crash on a m4 in monmouthshire . '},
#  {'id': '2000130',
#   'predict': 'a women have been taken to hospital after a car crash in a car crash in the . '},
#  {'id': '2000131',
#   'predict': 'a man accused of murdering a man who was a a a " a " " " a " " " , a court has heard . '},
#  {'id': '2000132',
#   'predict': 'a man who admitted a a prisoner who was a prison prison has been been charged with a prison . '},
#  {'id': '2000133',
#   'predict': "paralympic gold medallist medallist <unk> has been named the the 's of the year 's rio olympics . "},
#  {'id': '2000134',
#   'predict': 'the in in have have have have been a rally in the in the in the in the . '},
#  {'id': '2000135',
#   'predict': 'a man has been arrested on suspicion of attempted murder after a man was found in a . '},
#  {'id': '2000136',
#   'predict': "the 's biggest bank has has been to buy £ m m ( £ <unk> m ) to the the - . "},
#  {'id': '2000137',
#   'predict': "scotland have made the signing of scotland under-20s for the first - the season after beating scotland 's the - 0 . "},
#  {'id': '2000138',
#   'predict': 'a woman has died after a car crash in a car in gwynedd . '},
#  {'id': '2000139',
#   'predict': 'welsh boxer andrew selby says he will not " the " " the " of the " in the world \'s world '},
#  {'id': '2000140',
#   'predict': 'a crowd of the to the the of the in the european football league , says . '},
#  {'id': '2000141',
#   'predict': 'the exhibition of the of the of the has been the by the national library of the . '},
#  {'id': '2000142',
#   'predict': 'celtic manager manager derek adams says his side \'s to to the the " of the " " the " . '},
#  {'id': '2000143',
#   'predict': 'a man has been arrested on suspicion of murdering a woman who was found dead in a house in '},
#  {'id': '2000144',
#   'predict': 'a man has been charged with murdering a man who died after being hit by a car in a . '},
#  {'id': '2000145',
#   'predict': 'a rare of vintage has been sold by a former world war one of the has sold for auction . '},
#  {'id': '2000146',
#   'predict': 'at least 20 people have been killed in a attack in a somali capital in the somali capital mogadishu , officials say . '},
#  {'id': '2000147',
#   'predict': 'scotland \'s largest minister has said the has said a " to " " " " " " " " . '},
#  {'id': '2000148',
#   'predict': "a giant pumpkin has sold for auction for the world 's largest ever sold sold sold at auction for auction . "},
#  {'id': '2000149',
#   'predict': "the 's has been the has the first - of the the the the the box office chart . "},
#  {'id': '2000150',
#   'predict': "the of the of people are taking part of the world 's most famous in the . "},
#  {'id': '2000151',
#   'predict': 'a man has been charged with connection with a estimated street value of a in in in county antrim . '},
#  {'id': '2000152',
#   'predict': 'former president of the former president of the former president of the former president of the , '},
#  {'id': '2000153',
#   'predict': 'two people have been injured in a suspected attack on a house in in . '},
#  {'id': '2000154',
#   'predict': "kent 's batsmen dominated a one - day cup of the season as they beat derbyshire on a one - day cup . "},
#  {'id': '2000155',
#   'predict': "sauber <unk> has <unk> <unk> has been ruled out of the season 's world cup after suffering a crash crash in the . "},
#  {'id': '2000156',
#   'predict': '( close ) : us stocks closed lower on thursday , the the the rate rise in the . '},
#  {'id': '2000157',
#   'predict': 'police in the have have been charged with the alleged of of the of the , of the . '},
#  {'id': '2000158',
#   'predict': 'a of of a " rail lines in the has been a " of " " of " " . '},
#  {'id': '2000159',
#   'predict': 'prince charles <unk> has been airlifted to hospital after a helicopter in a a in in the . of the . '},
#  {'id': '2000160',
#   'predict': 'police police have clashed a protest against a demonstration in protest against the in the . '},
#  {'id': '2000161',
#   'predict': 'wrexham manager manager <unk> <unk> has been his first as as manager manager manager . '},
#  {'id': '2000162',
#   'predict': 'the will host the premier league games in the premier league , the the - the premier league , the the - - . '},
#  {'id': '2000163',
#   'predict': 'england prop joe marler has been his appeal for the " of the " of the " of the " of the " . '},
#  {'id': '2000164',
#   'predict': 'the olympic games will be the olympic games in rio 2016 , the olympic committee has announced . '},
#  {'id': '2000165',
#   'predict': 'torquay town have confirmed they will not to to their their league league league league league . '},
#  {'id': '2000166',
#   'predict': 'a new - in wales has been a to to " and " to " and " to " . '},
#  {'id': '2000167',
#   'predict': 'a man has been found guilty of murdering a man in a in a a a . '},
#  {'id': '2000168',
#   'predict': 'a taxi driver who was a a a a " a " has been a a " a " has been suspended . '},
#  {'id': '2000169',
#   'predict': 'a rare of a has been found in a a of a in a has been sold for auction . '},
#  {'id': '2000170',
#   'predict': 'a man has admitted causing the death of a man who died after a crash crash in a car crash in a . '},
#  {'id': '2000171',
#   'predict': 'league one side signed midfielder jack <unk> has signed a new one - year contract with the league one club . '},
#  {'id': '2000172',
#   'predict': 'league one side gillingham have signed defender midfielder midfielder midfielder <unk> on a one - year deal . '},
#  {'id': '2000173',
#   'predict': 'a teenager has been arrested on suspicion of attempted murder after a teenager was attacked in a . '},
#  {'id': '2000174',
#   'predict': "the 's of a has been fined for the to the to the its operations . "},
#  {'id': '2000175',
#   'predict': "the 's 's the world record has won the world record in the the world of the world grand prix . "},
#  {'id': '2000176',
#   'predict': 'a man has been a lawsuit over the death of a driving - driving crash in the us , has been . '},
#  {'id': '2000177',
#   'predict': 'a teacher who was a a school school school school has been a " a " " has been a " a " has been a court . '},
#  {'id': '2000178',
#   'predict': 'a man accused of murdering a man in a has been a court has ruled . '},
#  {'id': '2000179',
#   'predict': '( close ) : the ftse 100 closed lower on tuesday , the the of the the of the . '},
#  {'id': '2000180',
#   'predict': "a <unk> has been the the of the to the the the the the the the the race of the year 's "},
#  {'id': '2000181',
#   'predict': 'a have been killed in the deaths of a in in the , of the , of the . '},
#  {'id': '2000182',
#   'predict': 'sussex have signed former has signed a new contract - year contract with the championship club . '},
#  {'id': '2000183',
#   'predict': "the 's tennis association of the has been the the the of the year 's wimbledon , the . "},
#  {'id': '2000184',
#   'predict': 'a mother of a woman who was in a a she she was a " a " " , a court has heard . '},
#  {'id': '2000185',
#   'predict': 'sunderland midfielder danny <unk> has signed a new - year contract with the league one club . '},
#  {'id': '2000186',
#   'predict': "the number of northern ireland 's northern ireland has been a to the % in the , according to the latest report . "},
#  {'id': '2000187',
#   'predict': "<unk> <unk> has been sacked by the football association after a touchline ban on a touchline ban on saturday 's 2 - 0 defeat at the . "},
#  {'id': '2000188',
#   'predict': "us president donald trump has been a new york 's new york 's new york 's new york . "},
#  {'id': '2000189',
#   'predict': "british 's 's <unk> <unk> has become the first olympic games in the the world 's world championships in the . "},
#  {'id': '2000190',
#   'predict': 'a memorial service has been to the victims of a fire which destroyed a a of a . '},
#  {'id': '2000191',
#   'predict': 'a flood of a flood has been to be a to a a of a year . '},
#  {'id': '2000192',
#   'predict': 'a of of rubbish of rubbish of wales are being asked to be a to a . '},
#  {'id': '2000193',
#   'predict': 'the russian government has has a russian government to investigate the russian of the russian republic of '},
#  {'id': '2000194',
#   'predict': "facebook has been a photo of the 's facebook page of the 's facebook page . "},
#  {'id': '2000195',
#   'predict': 'the has has has has a its website that has been its customers in the . '},
#  {'id': '2000196',
#   'predict': 'a £ £ m m project to be a £ £ m in a £ to m the £ of m . '},
#  {'id': '2000197',
#   'predict': 'a new - has been a a a to a a a to improve the brain disease , a study has suggested . '},
#  {'id': '2000198',
#   'predict': 'a man who been jailed for a years after a a of a " of a " has been jailed for a years . '},
#  {'id': '2000199',
#   'predict': 'rangers manager derek mcinnes says he is " to " to the the the scottish premiership club . '},
#  {'id': '2000200',
#   'predict': 'the irish government has <unk> has has been a to the the of the stormont ) in the republic of ireland . '},
#  {'id': '2000201',
#   'predict': "a of of the been launched for a new of of the highlands 's "},
#  {'id': '2000202',
#   'predict': 'qualcomm has has has has has has has has has has said it is " to " in the us . '},
#  {'id': '2000203',
#   'predict': 'a scottish government has has been to a a wind farm in the scottish borders . '},
#  {'id': '2000204',
#   'predict': "scotland international cricket board has been appointed as the new chief executive of the women 's women 's "},
#  {'id': '2000205',
#   'predict': "tyrone <unk> 's late goal to the - 0 to win over westmeath on sunday night after a 2 - 0 win over westmeath at croke . "},
#  {'id': '2000206',
#   'predict': 'scarlets coach coach rob <unk> says he will not be " the the " of the the the the the the the the . '},
#  {'id': '2000207',
#   'predict': 'a food company has has been a to a a to a new in scotland . '},
#  {'id': '2000208',
#   'predict': 'former french side lille have signed former french ligue - germain <unk> as a new manager . '},
#  {'id': '2000209',
#   'predict': "wales ' association of wales ' association has warned the club 's to the the the the the . "},
#  {'id': '2000210',
#   'predict': 'a former head of the has been a of a " of " " " " , a " - of " . '},
#  {'id': '2000211',
#   'predict': 'a man has died after a car crash in a car in a . '},
#  {'id': '2000212',
#   'predict': 'the number of people are being to to the uk , according to the bank of the , according to the . . '},
#  {'id': '2000213',
#   'predict': 'a woman has been a after a a a a a a a a a a a a a a . '},
#  {'id': '2000214',
#   'predict': 'the former soldier has been a a the us military to the the he was " to " the " , the us . '},
#  {'id': '2000215',
#   'predict': 'a rail has been suspended for a to a rail conductors of a rail conductors in the rail line . '},
#  {'id': '2000216',
#   'predict': "china 's economy grew in the % in in the , , , , the , according to the , official figures . "},
#  {'id': '2000217',
#   'predict': 'a has been a of a , in the , , , a of a , a to have been . '},
#  {'id': '2000218',
#   'predict': "shares in the us owner of the , has been a a a a the company 's "},
#  {'id': '2000219',
#   'predict': 'a new hotel hotel in the has been to be restored after a years . '},
#  {'id': '2000220',
#   'predict': 'newport county will be newport county championship match between newport , newport county , the postponed . '},
#  {'id': '2000221',
#   'predict': 'a former president of the has has been a a a - after the the of a '},
#  {'id': '2000222',
#   'predict': 'league town midfielder louis van has been ruled out for the rest of the season after suffering a knee injury . '},
#  {'id': '2000223',
#   'predict': 'a new college has been a to a new campus in pembrokeshire has been appointed . '},
#  {'id': '2000224',
#   'predict': "bromley <unk> 's late goal of the season as they beat bromley racked a 2 - 0 win over woking . "},
#  {'id': '2000225',
#   'predict': 'graeme mcdowell carded a first - round lead to the the round of the the round of the round of the us open . '},
#  {'id': '2000226',
#   'predict': "the chief of the has 's new chief executive of the has been appointed as the new chief executive . "},
#  {'id': '2000227',
#   'predict': "the european union have fallen sharply on tuesday , after the european union , the the the 's "},
#  {'id': '2000228',
#   'predict': 'a turkish government has has been killed in a car bomb attack in the syrian capital , '},
#  {'id': '2000229',
#   'predict': 'a woman has been charged with the abduction of a girl in a in a . '},
#  {'id': '2000230',
#   'predict': 'a ship has been launched on a derelict in the river tyne has been a £ . m . '},
#  {'id': '2000231',
#   'predict': 'a man has been arrested on suspicion of murder after a man was found in a house in in . '},
#  {'id': '2000232',
#   'predict': 'a new £ m m has been in in the city centre in the city centre . '},
#  {'id': '2000233',
#   'predict': 'the of of the artist artist sir john , has died at the age of 87 . '},
#  {'id': '2000234',
#   'predict': 'a company company has been fined £ 7,500 for £ 7,500 after it was a to £ £ . '},
#  {'id': '2000235',
#   'predict': 'a businessman who has been a to a hotel in the to a hotel after it was a to a hotel . '},
#  {'id': '2000236',
#   'predict': 'brazilian president minister <unk> <unk> has been charged with the alleged of of a corruption scandal . '},
#  {'id': '2000237',
#   'predict': "england pace bowler <unk> <unk> has been ruled out of the 's cricket squad for the second test of the the . "},
#  {'id': '2000238',
#   'predict': 'residents in a have been in a after a fire at a shop in <unk> . '},
#  {'id': '2000239',
#   'predict': "cardiff blues - back to the a point of the women 's super league one - offs in cardiff . "},
#  {'id': '2000240',
#   'predict': 'a man who who was a a a a " police officer has been jailed for a years . '},
#  {'id': '2000241',
#   'predict': 'a couple who was a a a - year - old boy has been a by a " after the owner of a . '},
#  {'id': '2000242',
#   'predict': 'a man has been found guilty of murdering a man who was found stabbed in a house in '},
#  {'id': '2000243',
#   'predict': 'a have been paid to a £ of of a missing of a man who was found in a burglary . '},
#  {'id': '2000244',
#   'predict': "american 's graeme mcdowell has his first - round - - the wgc to win the wgc championship in the . "},
#  {'id': '2000245',
#   'predict': 'the <unk> has said he is " to " the uk \'s the uk \'s the uk \'s '},
#  {'id': '2000246',
#   'predict': 'a man has been killed in a car in a in in a city centre in the capital , killing a people , police say . '},
#  {'id': '2000247',
#   'predict': 'league one side oldham athletic have signed midfielder midfielder midfielder midfielder on loan until the end of the season . '},
#  {'id': '2000248',
#   'predict': 'two men have been arrested on suspicion of terrorism offences related terrorism . '},
#  {'id': '2000249',
#   'predict': 'a man has died after a a a a a a a a a car crash in the , has died . '},
#  {'id': '2000250',
#   'predict': 'league one side gillingham have signed midfielder - back on a one - year contract . '},
#  {'id': '2000251',
#   'predict': "liverpool 's has been the club 's to the the club 's stadium stadium . "},
#  {'id': '2000252',
#   'predict': "everton manager everton defender has been ruled out of the 's premier league title with everton and everton . "},
#  {'id': '2000253',
#   'predict': 'exeter city manager paul tisdale says he is " to " to " the the league league . '},
#  {'id': '2000254',
#   'predict': 'a former who of a has been fined £ 30,000 in damages from a court in the . '},
#  {'id': '2000255',
#   'predict': 'us stocks giant blackstone has has a a - the - of the us - the dollar - dollar dollar dollar dollar dollar dollar . '},
#  {'id': '2000256',
#   'predict': 'the sequel of the the the the sequel of the , the , , , , , according to the new . '},
#  {'id': '2000257',
#   'predict': 'a £ - m has been launched by the £ m m station in london . '},
#  {'id': '2000258',
#   'predict': 'a migrants from migrants from the mediterranean island of calais , the mediterranean island of calais , the mediterranean . '},
#  {'id': '2000259',
#   'predict': 'a man who killed a a crash on a a a a crash has been jailed for life . '},
#  {'id': '2000260',
#   'predict': 'a man has appeared in court charged with murdering a man in a in a . '},
#  {'id': '2000261',
#   'predict': 'a new £ m m project to build a £ m m in the north sea has been . '},
#  {'id': '2000262',
#   'predict': 'the world conker championships will be the at the world championships championships championships , organisers have been . '},
#  {'id': '2000263',
#   'predict': "the 's parliament has voted overwhelmingly to the the 's presidential election in the . "},
#  {'id': '2000264',
#   'predict': 'the number of people wales wales wales wales wales has risen in the , , figures show . '},
#  {'id': '2000265',
#   'predict': 'a men have been charged with connection with the alleged of of a police officer . '},
#  {'id': '2000266',
#   'predict': 'a food food food has been a to in a food standards in the a , of the food standards . '},
#  {'id': '2000267',
#   'predict': 'league two side have have have signed midfielder <unk> <unk> from the city on a season - long loan . '},
#  {'id': '2000268',
#   'predict': "a new of the belfast 's biggest building in belfast has been has been . "},
#  {'id': '2000269',
#   'predict': 'a man has been shot in a belfast in in belfast . '},
#  {'id': '2000270',
#   'predict': 'a man accused of murdering a man who was a a a " " " " a " has been " , a court has heard . '},
#  {'id': '2000271',
#   'predict': 'the us senate has voted overwhelmingly to to a bill to to the to to the the to the the us . '},
#  {'id': '2000272',
#   'predict': 'the duchess of the has been a a to - up to the the , the , the . '},
#  {'id': '2000273',
#   'predict': 'the number of pups pups in the uk in the , the the of of the . '},
#  {'id': '2000274',
#   'predict': "wales wing - <unk> has been ruled out of the 's six nations squad for the six nations in the . "},
#  {'id': '2000275',
#   'predict': 'a have been found to be a a a a a a a a a a a a . '},
#  {'id': '2000276',
#   'predict': 'a man has been stabbed in a in in a in in in west belfast . '},
#  {'id': '2000277',
#   'predict': "the us supreme court has ruled a new president donald trump 's presidential candidate donald trump 's presidential candidate . "},
#  {'id': '2000278',
#   'predict': "kris <unk> and his second - - win to win the world grand prix in the world 's grand prix . "},
#  {'id': '2000279',
#   'predict': "the world of the has the the of the the the the the of the the 's 's has been . "},
#  {'id': '2000280',
#   'predict': "oxford united 's a - - league two play - off places as they beat league two - league two . "},
#  {'id': '2000281',
#   'predict': 'the wimbledon and wimbledon are to to the the the . '},
#  {'id': '2000282',
#   'predict': 'a man has been charged with the a of a student who died in a crash in a . '},
#  {'id': '2000283',
#   'predict': 'the number of people have been in the in the , of the , the , according to the figures . '},
#  {'id': '2000284',
#   'predict': "a petition calling a to a a a a a a a to a the to the the city of the city 's "},
#  {'id': '2000285',
#   'predict': 'a man who who was a a a a a a a a has been jailed for life . '},
#  {'id': '2000286',
#   'predict': 'oil giant oil has has oil oil and gas oil and gas sector has said it will be cut up for the first time . '},
#  {'id': '2000287',
#   'predict': "france 's <unk> <unk> has been banned for a football association for a football association for a football association . "},
#  {'id': '2000288',
#   'predict': 'a new - of a " to " a " " of " " in the " of " " , a new - has said . '},
#  {'id': '2000289',
#   'predict': "israel 's president has approved a deal to the israeli - and - israeli - . "},
#  {'id': '2000290',
#   'predict': 'a former of of the has has been appointed as the new chief executive . '},
#  {'id': '2000291',
#   'predict': "indian authorities have been a a in the indian state of the the country 's military base "},
#  {'id': '2000292',
#   'predict': 'league one side signed have signed midfielder - back from a on a one - year deal . '},
#  {'id': '2000293',
#   'predict': 'a of of beaver has been a to to a a to a to a to a to a . '},
#  {'id': '2000294',
#   'predict': "england 's a a - match between the first match in the first - match against england in the first - match against england . "},
#  {'id': '2000295',
#   'predict': "former england manager of the has been named as the coach of the year 's euro 2016 . "},
#  {'id': '2000296',
#   'predict': 'england \'s bowler stuart broad is " to " the " after the \'s of the \'s '},
#  {'id': '2000297',
#   'predict': 'the of the first time of the and the and the are being the to the . '},
#  {'id': '2000298',
#   'predict': 'a woman who of a a girl in a has been told she was " to " her her to her her . '},
#  {'id': '2000299',
#   'predict': "england 's paul casey and a shot - shot lead at the the round of the women 's open at the . "},
#  {'id': '2000300',
#   'predict': 'a council council has been a to a council council council council council council council to the the council . '},
#  {'id': '2000301',
#   'predict': 'welsh boxer says he is " " " " " the " " the " of the " , says promoter eddie hearn . '},
#  {'id': '2000302',
#   'predict': 'a to a new £ in in a bid to be a in a bid to save a . '},
#  {'id': '2000303',
#   'predict': 'a former police officer has been arrested on suspicion of murdering a man in a a in a . '},
#  {'id': '2000304',
#   'predict': 'sir bradley has been the the the of the the the the the the the the the the the the the the the . '},
#  {'id': '2000305',
#   'predict': 'a us - old man has been arrested in connection with the alleged of of a - old - old boy in a . '},
#  {'id': '2000306',
#   'predict': 'a former soldier who was a a a a a a a has been jailed for a years . '},
#  {'id': '2000307',
#   'predict': 'a man has been arrested on suspicion of a a a a a in in a . '},
#  {'id': '2000308',
#   'predict': 'league one side <unk> have signed signed defender <unk> <unk> from french side <unk> <unk> on a undisclosed fee . '},
#  {'id': '2000309',
#   'predict': 'police have appealed for witnesses of a man who want to trace a man who want to trace a man in a glasgow . '},
#  {'id': '2000310',
#   'predict': 'bus services firm has announced a new bus services bus services in the to to the . '},
#  {'id': '2000311',
#   'predict': 'a bank bank has been a bank bank bank bank bank bank has been a to a bank bank . '},
#  {'id': '2000312',
#   'predict': 'the bank of the has said it is to to the to the the to the the of the . '},
#  {'id': '2000313',
#   'predict': 'ellie downie has been her first female at the rio olympics in rio , the her her to her her . '},
#  {'id': '2000314',
#   'predict': 'the sequel of the sequel of the sequel of the film , has been released by the film of the . '},
#  {'id': '2000315',
#   'predict': 'a man has appeared in court charged with murdering a man who was stabbed in a in a . '},
#  {'id': '2000316',
#   'predict': 'mae <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> '},
#  {'id': '2000317',
#   'predict': "serena williams will not be the wimbledon 's to open a wildcard wimbledon because of the wimbledon 's "},
#  {'id': '2000318',
#   'predict': "scotland beat scotland 's their hopes to a 2 - 0 win over scotland in the first - finals of the . "},
#  {'id': '2000319',
#   'predict': 'a man who stabbed a woman who was a a a " " " " " a " " has been jailed for life . '},
#  {'id': '2000320',
#   'predict': 'a new of doctors have to be a to a new maternity services in the uk . '},
#  {'id': '2000321',
#   'predict': 'league one side gillingham have signed former midfielder <unk> <unk> on a one - year deal . '},
#  {'id': '2000322',
#   'predict': "league have signed former midfielder conor o'shea on a two - year deal following his release by the . "},
#  {'id': '2000323',
#   'predict': 'the us president donald trump has said he will not to to the the to the the the the country . '},
#  {'id': '2000324',
#   'predict': 'a woman has been been arrested in a in the republic of ireland after a sexual abuse . '},
#  {'id': '2000325',
#   'predict': 'irish police have seized a £ of m euros ( £ m ) £ m ) £ m ) in the republic of ireland . '},
#  {'id': '2000326',
#   'predict': 'a security alert has been found in a controlled explosion in a . '},
#  {'id': '2000327',
#   'predict': 'a new wales hospital has been a in a new admissions in in the . '},
#  {'id': '2000328',
#   'predict': 'barcelona \'s barcelona fans have been a " " " " " in the europa league match against barcelona . '},
#  {'id': '2000329',
#   'predict': 'the first - of the has been the the the the the the the the '},
#  {'id': '2000330',
#   'predict': 'a number of people in the uk are being treated as a " obesity to improve the , a new report . '},
#  {'id': '2000331',
#   'predict': 'a of the copyrighted of a a a a stunt stunt in the has been a . '},
#  {'id': '2000332',
#   'predict': "a new - has been the has been a a - - of the the 's of the , the the of the "},
#  {'id': '2000333',
#   'predict': 'a man has died after a crash involving a car in a crash in the . '},
#  {'id': '2000334',
#   'predict': 'wales rugby union <unk> <unk> has been suspended for the to a a - doping . '},
#  {'id': '2000335',
#   'predict': 'raith rovers have signed striker <unk> <unk> from dundee united on a one - year deal . '},
#  {'id': '2000336',
#   'predict': "australia 's their unbeaten run to the a one - day cup of the day - day cup of the day - day series i"},
#  {'id': '2000337',
#   'predict': 'a man has been arrested on suspicion of causing death a a car in a car in a . '},
#  {'id': '2000338',
#   'predict': 'england wing - back is set to miss the for the six nations match against england in the six nations match against england . '},
#  {'id': '2000339',
#   'predict': 'a us has been sentenced to pay a us of a of of of a us state of that was found guilty of the . '},
#  {'id': '2000340',
#   'predict': 'a man has been rescued after a boat after a boat off the sea in the . '},
#  {'id': '2000341',
#   'predict': 'south korea has approved a controversial - million of the to the the of nuclear power . '},
#  {'id': '2000342',
#   'predict': 'a man accused of murdering a woman - girlfriend to death has been told he was " a " " , a court has heard . '},
#  {'id': '2000343',
#   'predict': "former <unk> has been appointed as the of the club of the after being held by the club 's "},
#  {'id': '2000344',
#   'predict': "the 's has been the ebola has been the the of ebola , the the of the ebola outbreak of the disease . "},
#  {'id': '2000345',
#   'predict': 'a former head teacher has been appointed as a " - " " " " " , the head of the head of the . . '},
#  {'id': '2000346',
#   'predict': 'a man has died after a car crash in a car in in . '},
#  {'id': '2000347',
#   'predict': 'anthony joshua says he is " " " " his ibf world heavyweight title after he he is " " " " " . '},
#  {'id': '2000348',
#   'predict': 'british number one johanna konta reached the first round of the european open to win the first - round of the '},
#  {'id': '2000349',
#   'predict': 'polling stations across wales have been a to in the election election election . '},
#  {'id': '2000350',
#   'predict': 'a rail station station has been a " " " " " " " " " " " . '},
#  {'id': '2000351',
#   'predict': 'a police has been a to a police police and crime commissioner ( pcc ) . '},
#  {'id': '2000352',
#   'predict': "russia 's governing body has been banned from the rio olympics after failing to compete the rio olympics . "},
#  {'id': '2000353',
#   'predict': 'police in the have have been found in a of of a a a in the the of of the . '},
#  {'id': '2000354',
#   'predict': "hong kong 's democracy has been a to the the of the 's election . "},
#  {'id': '2000355',
#   'predict': "a city boss <unk> <unk> has been the women 's women 's women 's women 's women 's europa league match against <unk> . "},
#  {'id': '2000356',
#   'predict': 'a man has been charged with the murder of a woman who died after being found in a . '},
#  {'id': '2000357',
#   'predict': 'a dog has been killed by a dog in a dog in a dog has been named by police . '},
#  {'id': '2000358',
#   'predict': 'a fire fire has been a a fire in a fire in a . '},
#  {'id': '2000359',
#   'predict': 'liverpool defender jan <unk> has been ruled out for the rest of the season after suffering a knee ligament damage . '},
#  {'id': '2000360',
#   'predict': 'the author of the has has been revealed he is to the the first time in the . '},
#  {'id': '2000361',
#   'predict': 'a man who who a a a " dangerous " " " a " " " " " a " " " , a inquest has heard . '},
#  {'id': '2000362',
#   'predict': 'a new of of the has been a a a bit to the the of the . '},
#  {'id': '2000363',
#   'predict': 'a body has been found in a search for a man in a . '},
#  {'id': '2000364',
#   'predict': 'a man has died after being hit by a car in a . '},
#  {'id': '2000365',
#   'predict': 'tranmere kept their first of the national league with a comfortable victory over tranmere rovers . '},
#  {'id': '2000366',
#   'predict': 'a have been a the to a a of a a the to the the of a dig - old - old . . '},
#  {'id': '2000367',
#   'predict': 'the airline airline indigo has announced its flights to flights , the airline airlines . '},
#  {'id': '2000368',
#   'predict': 'a £ of m dementia in dementia in in in in in in in wales has been approved by a . '},
#  {'id': '2000369', 'predict': 'a fire has been a fire in a in the . '},
#  {'id': '2000370',
#   'predict': '<unk> <unk> hit a century century as the wickets as a wickets as a wickets to the the - day of the first day of the season . '},
#  {'id': '2000371',
#   'predict': 'british number one johanna konta has been the the aegon open at the aegon open . '},
#  {'id': '2000372',
#   'predict': 'a man has been fined after a a a a a a a a a a a a a in the . '},
#  {'id': '2000373',
#   'predict': 'a police has been a to a guns and crime in in the in the . '},
#  {'id': '2000374',
#   'predict': "a museum of edinburgh 's oldest museum has has been named as the of the "},
#  {'id': '2000375',
#   'predict': 'a police have been the the of of a " of of " of the " of the " of the " . '},
#  {'id': '2000376',
#   'predict': 'brighton defender sam <unk> will miss the rest of the season after dislocating his leg injury . '},
#  {'id': '2000377',
#   'predict': 'the actor of the actor , who played the actor , has died at the age of the , has died aged 88 . '},
#  {'id': '2000378',
#   'predict': "fifa president sepp blatter has been appointed president president president sepp blatter 's president of the president of the . "},
#  {'id': '2000379',
#   'predict': 'a number of people in the victims in a child abuse in has been launched by the . '},
#  {'id': '2000380',
#   'predict': 'wales rugby union has says he is " " " " " " " " " " " " " " " " . '},
#  {'id': '2000381',
#   'predict': 'a new of the the of of the author of the author of the has been has been has been a by the . '},
#  {'id': '2000382',
#   'predict': 'a pilot who died after a light aircraft crashed in a plane crash in the has been named by police . '},
#  {'id': '2000383',
#   'predict': 'syrian forces forces have been a to to the to the the to to the the to the the conflict with the conflict between the conflict . '},
#  {'id': '2000384',
#   'predict': 'league one side <unk> have signed midfielder <unk> <unk> on a one - year deal . '},
#  {'id': '2000385',
#   'predict': 'a man who been jailed for a a a - terror attack in a has been jailed for a years . '},
#  {'id': '2000386',
#   'predict': 'a us presidential has been a a the us presidential election in the us presidential election in the . '},
#  {'id': '2000387',
#   'predict': "the scottish government has been the to the the the the the the uk 's to the the the the the . "},
#  {'id': '2000388',
#   'predict': 'a man has been injured after a explosion explosion in a a a in a . '},
#  {'id': '2000389',
#   'predict': 'a of people have been the in the spanish capital of the the capital of spain . '},
#  {'id': '2000390',
#   'predict': "the shortlist of the shortlist of the shortlist of the shortlist for the year 's bafta prize prize . "},
#  {'id': '2000391',
#   'predict': '<unk> <unk> scored twice as as as as as as as as as as the beat 10-man to the league one . '},
#  {'id': '2000392',
#   'predict': 'the international airlines indigo has has to the a of the to the the to the the '},
#  {'id': '2000393',
# ...
#  {'id': '2000871',
#   'predict': 'a £ has has been fined £ a £ after a to a a the " of a " " . '},
#  {'id': '2000872',
#   'predict': 'forfar athletic moved to the scottish league league two with a 2 - 0 win over the . '},
#  {'id': '2000873',
#   'predict': 'a man has appeared in court charged with murdering a man - old man in londonderry . '},
#  {'id': '2000874',
#   'predict': 'a hospital hospital has been been closed to hospital after a a of a " a " " . '},
#  {'id': '2000875',
#   'predict': 'a people have been arrested in the mexican city of sao paulo , , officials say they have been to to the . '},
#  {'id': '2000876',
#   'predict': "british number one roger federer has withdrawn from the 's open - the first round of the aegon open . "},
#  {'id': '2000877',
#   'predict': 'a man has been arrested on suspicion of murdering a man who was arrested on suspicion of murder . '},
#  {'id': '2000878',
#   'predict': 'a council has been to to a to a a to a a a a road to a a a . '},
#  {'id': '2000879',
#   'predict': 'a man has been charged with murdering a man in a belfast man in the . '},
#  {'id': '2000880',
#   'predict': 'a teenager has been arrested on suspicion of attempted murder after a teenager was stabbed in a school school . '},
#  {'id': '2000881',
#   'predict': 'barcelona have signed barcelona forward neymar <unk> from barcelona for the end of the season . '},
#  {'id': '2000882',
#   'predict': 'us president donald trump has said she will not be " to " " " " the " " " " " " . '},
#  {'id': '2000883',
#   'predict': 'a man has been charged with terrorism offences after a terror attack in '},
#  {'id': '2000884',
#   'predict': 'league have have have have been released by league two - and - and - <unk> and midfielder michael <unk> . '},
#  {'id': '2000885',
#   'predict': 'the aerospace engineering firm has has said it expects to cut its first - year profit in the year . '},
#  {'id': '2000886',
#   'predict': "serena williams will her first round of the women 's singles title with a 6 - 3 6 - 3 6 - 3 6 - 3 6 - 3 6 - 3 6 - 3 win over the . "},
#  {'id': '2000887',
#   'predict': 'a giant that has been a a a a a in a " after a a a a . '},
#  {'id': '2000888',
#   'predict': 'the duke of cambridge have been the first of the the the the the the the the . '},
#  {'id': '2000889',
#   'predict': "paralympian - old boy has been has been a a tumour in the world 's world cup of the . "},
#  {'id': '2000890',
#   'predict': 'a giant which has been a a " " " " " " " a " " has been found in a of the . '},
#  {'id': '2000891',
#   'predict': 'a kitten has been reunited with a car after a car crashed into a car in a . '},
#  {'id': '2000892',
#   'predict': 'a man has died after a crash in a a in in the cairngorms . '},
#  {'id': '2000893',
#   'predict': 'staff at the university of the have voted to strike action against a dispute over the . '},
#  {'id': '2000894',
#   'predict': 'a £ has been to to a £ to m flood in the river of in the borders . '},
#  {'id': '2000895',
#   'predict': "the ireland 's inquiry has been a inquiry into the inquiry into the of abuse abuse abuse and the . "},
#  {'id': '2000896',
#   'predict': 'a us - has been sentenced to a a of of a school in a has been arrested after a was found guilty of a . '},
#  {'id': '2000897',
#   'predict': "a 's air force has to be flying flying flying flying flying flying flying at the shoreham air disaster . "},
#  {'id': '2000898',
#   'predict': 'a court in the has been a a a a the - of the the of a journalist journalist . '},
#  {'id': '2000899',
#   'predict': 'a footballer footballer footballer has been arrested on suspicion of murder after a woman was a in a . '},
#  {'id': '2000900',
#   'predict': 'former education minister has <unk> has has been appointed as the new head of the '},
#  {'id': '2000901',
#   'predict': 'a least people people have been killed in a train derailed in the the of of the . '},
#  {'id': '2000902',
#   'predict': "the stars of the the 's most famous stars of the uk to be to to a new . "},
#  {'id': '2000903',
#   'predict': 'the stormont committee has said it will not be the to the the assembly of the assembly of the stormont committee ( <unk> ) ) . '},
#  {'id': '2000904',
#   'predict': "australia 's most popular record record record record record in the , australia , australia . "},
#  {'id': '2000905',
#   'predict': 'a former police officer has been been arrested on suspicion of historical sex offences . '},
#  {'id': '2000906',
#   'predict': 'a man has been arrested on suspicion of a a bomb disposal in a a in in a . '},
#  {'id': '2000907',
#   'predict': 'chelsea have have been a to a a a after a video of a " after a " of a " . '},
#  {'id': '2000908',
#   'predict': 'apple has has been a legal battle to the us the to to the the . '},
#  {'id': '2000909',
#   'predict': 'a man has been shot dead in a a - year - old boy in a in a . '},
#  {'id': '2000910',
#   'predict': 'a student who was fined £ a a a a a a a a a a a has been fined £ <unk> . '},
#  {'id': '2000911',
#   'predict': 'cardiff city have signed former cardiff city defender rhys healey on a two - year deal . '},
#  {'id': '2000912',
#   'predict': 'a church of a to to restore a church in the to a church in the . '},
#  {'id': '2000913',
#   'predict': 'wales wing - half has signed a new contract with the contract with the . '},
#  {'id': '2000914',
#   'predict': 'the of african have have been a to to the a of a bird of of the birds of the of the . '},
#  {'id': '2000915',
#   'predict': 'london irish manager michael o\'neill says he is pleased to " " " " " the " " " " " " . '},
#  {'id': '2000916',
#   'predict': 'a ambulance ambulance has apologised after a patient patient patient after a patient patient in a ambulance ambulance in a . '},
#  {'id': '2000917',
#   'predict': 'a man has been jailed for a a a a a a a a a a a " a " - a " . '},
#  {'id': '2000918',
#   'predict': 'mae <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> '},
#  {'id': '2000919',
#   'predict': 'mae <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> '},
#  {'id': '2000920',
#   'predict': 'a new of of the , the , in the us , has been a new york . '},
#  {'id': '2000921',
#   'predict': 'salford red devils coach rob baxter has been appointed as the rugby league side . '},
#  {'id': '2000922',
#   'predict': 'the rugby league cup will be the to the the the the the the the the cup of the season . '},
#  {'id': '2000923',
#   'predict': 'a to a new hospital in in a hospital in hospital has been " by the " . '},
#  {'id': '2000924',
#   'predict': 'a woman has been taken to hospital after a woman in a in a in in belfast . '},
#  {'id': '2000925',
#   'predict': 'the us has has said it is " the " " of the " of the " , the the of the syrian , the un - assad <unk> , the un - assad <unk> . '},
#  {'id': '2000926',
#   'predict': 'a new of in belfast and galloway and galloway and the have been announced . '},
#  {'id': '2000927',
#   'predict': 'a baby born in the zoo in the has been the the of the , the , the birth of a birth . '},
#  {'id': '2000928',
#   'predict': "ireland 's a a - - wicket in the sri lanka in the first - day international series in the . "},
#  {'id': '2000929',
#   'predict': 'a new housing housing has been the in the uk has been given a new - . '},
#  {'id': '2000930',
#   'predict': 'the of the of the of the star wars movie , the , has been released by the in the . '},
#  {'id': '2000931',
#   'predict': 'bath have signed australia international <unk> van der merwe on a two - year deal . '},
#  {'id': '2000932',
#   'predict': 'a than 200 people have been killed in nepal earthquake in nepal . '},
#  {'id': '2000933',
#   'predict': "the number of northern ireland 's sector sector slowed by the % in the , according to the . "},
#  {'id': '2000934',
#   'predict': 'a lorry driver has crashed into a motorway in the m1 , a court has heard . '},
#  {'id': '2000935',
#   'predict': 'a man who admitted jailed for a a a - old jail sentence for a years has been jailed for jail . '},
#  {'id': '2000936',
#   'predict': 'a woman has been rescued from a house fire in a house fire in a house fire . '},
#  {'id': '2000937',
#   'predict': 'a former us has been a has been a court has been a court in the us state ( <unk> ) , a court has heard . '},
#  {'id': '2000938',
#   'predict': 'swansea city \'s <unk> says he has been " a " racist comments about the " he racially abused " " a " . '},
#  {'id': '2000939',
#   'predict': 'police have been a the match at the football league match between the scottish football league match . '},
#  {'id': '2000940',
#   'predict': 'a man who was shot in a a in in a has been named as police . '},
#  {'id': '2000941',
#   'predict': "china has been a of china 's to china 's china - the country 's "},
#  {'id': '2000942',
#   'predict': 'a woman has been woman was attacked in a supermarket in edinburgh . '},
#  {'id': '2000943', 'predict': 'a man has died after a crash in a car in a . '},
#  {'id': '2000944',
#   'predict': "the have been the 's of the 's football league after the football association of the football association . "},
#  {'id': '2000945',
#   'predict': "the 's has been banned from the 's of the 's 's anti - doping agency ( <unk> ) . "},
#  {'id': '2000946',
#   'predict': 'manchester city have signed striker striker striker striker striker striker striker matt crooks from a undisclosed fee . '},
#  {'id': '2000947',
#   'predict': "portadown have been the 's of the football league after a after a a - old - old - old - . "},
#  {'id': '2000948',
#   'predict': "china 's car maker has has has been its first in the year 's "},
#  {'id': '2000949',
#   'predict': 'the in the have fallen to the % in the , the , the , the , the , the the , the the of the . '},
#  {'id': '2000950',
#   'predict': "the 's of the the the of the , the , the , the , has been revealed . "},
#  {'id': '2000951',
#   'predict': 'us - commerce giant macy has reported a fall in profits in the quarter quarter profits in the first quarter of the year . '},
#  {'id': '2000952',
#   'predict': 'rangers have signed former england midfielder harry kane as their new contract with the super league club . '},
#  {'id': '2000953',
#   'predict': 'a court in brazil has sentenced a man who of a in a , the the of of a . '},
#  {'id': '2000954',
#   'predict': 'a fireworks fireworks fireworks in the fireworks of the fireworks o'},
#  {'id': '2000955',
#   'predict': 'a yellow weather warning warning warning of heavy rain and heavy rain in '},
#  {'id': '2000956',
#   'predict': "great britain 's olympic gold medallist gold in the world cup final in the final of the world 's world championships in "},
#  {'id': '2000957',
#   'predict': 'a have been a to a a gas leak in a gas leak in a gas leak . '},
#  {'id': '2000958',
#   'predict': 'a of a a £ to m library of a a of of a has been opened . '},
#  {'id': '2000959',
#   'predict': "great britain 's olympic gold medallist rebecca <unk> has won the first gold medal at the rio olympics . "},
#  {'id': '2000960',
#   'predict': 'the united states have <unk> has been the youngest player of the after a crash crash in the . '},
#  {'id': '2000961',
#   'predict': 'a train has been fined after a after a train was hit by a train in a . '},
#  {'id': '2000962',
#   'predict': "great britain 's olympic champion medallist laura robson has announced to will be the the the the the world 's world championships . "},
#  {'id': '2000963',
#   'predict': 'walsall manager paul clement says he is " " " " the " " to the the " of the " " . '},
#  {'id': '2000964',
#   'predict': 'a comet has has been a comet has been a comet , has been discovered . '},
#  {'id': '2000965',
#   'predict': 'jockey jockey jockey has been the to the the of the after a a a a a a a a race . '},
#  {'id': '2000966',
#   'predict': 'a man has appeared in court charged with murdering a man in a . '},
#  {'id': '2000967',
#   'predict': 'a former who who a a " a " " " " a " has been a " a " " . '},
#  {'id': '2000968',
#   'predict': 'a group of people have been a to a in the in wales . '},
#  {'id': '2000969',
#   'predict': 'the has of a drug drug has has been has been a " drug " drug " . '},
#  {'id': '2000970',
#   'predict': "a woman has has been the first celebrity of of the her the , after her boyfriend 's "},
#  {'id': '2000971',
#   'predict': 'pianist pianist <unk> <unk> has died at the age of age , aged , aged 93 . '},
#  {'id': '2000972',
#   'predict': "the city council has to a a of the club 's stadium stadium stadium . "},
#  {'id': '2000973',
#   'predict': "wales ' coach <unk> <unk> has been ruled out of the 's euro 2016 qualifying after being france 's euro 2016 qualifying . "},
#  {'id': '2000974',
#   'predict': 'the first - of the has been the the the to the the the '},
#  {'id': '2000975',
#   'predict': 'a church of a church in a has been found to a a man who went missing from a . . '},
#  {'id': '2000976',
#   'predict': 'a man has been arrested after a robbery at a shop in a . '},
#  {'id': '2000977',
#   'predict': 'england have signed south africa international bowler <unk> <unk> on a three - year deal . '},
#  {'id': '2000978',
#   'predict': 'a woman who died after falling into a water in a a a a her home in her home has been her , a inquest has heard . '},
#  {'id': '2000979',
#   'predict': "the first female candidates of the women 's women in the have been the first time of the first time . "},
#  {'id': '2000980',
#   'predict': "the ireland 's deputy has said the has said the the of the northern ireland 's northern ireland . "},
#  {'id': '2000981',
#   'predict': 'league one side gillingham have parted to the with the league one - year deal with the league one club . '},
#  {'id': '2000982',
#   'predict': 'a in the are being urged to to a the number of the in the , the '},
#  {'id': '2000983',
#   'predict': "the is to be the to the uk 's to the the uk 's . "},
#  {'id': '2000984',
#   'predict': 'league one side signed midfielder matt crooks on a two - year contract with the league one club . '},
#  {'id': '2000985',
#   'predict': 'the number of migrants have been in the in the in the in the , the , the , the , says . '},
#  {'id': '2000986',
#   'predict': 'wales manager jaap stam says the club \'s " " " " " " , says he is " " " " . '},
#  {'id': '2000987',
#   'predict': 'ghana coach avram <unk> has been named as the coach of the year - year contract with the african coach . '},
#  {'id': '2000988',
#   'predict': 'a man - old man has been charged with the a of a alleged assault in a belfast city centre . '},
#  {'id': '2000989',
#   'predict': 'manchester united manager jose mourinho has been fined £ 1 m for a touchline ban on a football association . '},
#  {'id': '2000990',
#   'predict': 'a pilot jets has been to the shoreham air crash in the shoreham air crash . '},
#  {'id': '2000991',
#   'predict': 'a driver has been arrested on suspicion of causing a car of a a a a in a . '},
#  {'id': '2000992',
#   'predict': "( close ) : london 's leading shares index closed higher on tuesday , with the shares in the ftse 100 . "},
#  {'id': '2000993',
#   'predict': 'a man has died after a after a pub in a pub in a pub in a . '},
#  {'id': '2000994',
#   'predict': 'a man who who was to to a a after he was " to " after he was " to his " after he was " to the . '},
#  {'id': '2000995',
#   'predict': 'south africa \'s <unk> <unk> has been banned for the " after being " by the cricket after being banned for the . '},
#  {'id': '2000996',
#   'predict': 'the rugby world cup will be the to the the rugby world cup of nations , says it is to to be a new . '},
#  {'id': '2000997',
#   'predict': "england 's a a - - the first - of the first - day cup of the first - day cup of the . "},
#  {'id': '2000998',
#   'predict': 'league one side gillingham have signed midfielder midfielder midfielder midfielder midfielder midfielder midfielder midfielder midfielder <unk> on loan until the end of the season . '},
#  {'id': '2000999',
#   'predict': 'a suicide bomber has killed in afghanistan , the pakistani capital kabul , kabul , '},
#  ...]

# %%
import json
PATH_save = "/disk2/iping/NTU_ADL/ADL_hw1/for_testing/"
filename_save = 'output_attn_1e04'
with open(PATH_save+filename_save+'.jsonl', 'w') as outfile:
    for entry in ans_jsonl:
        json.dump(entry, outfile)
        outfile.write('\n')
